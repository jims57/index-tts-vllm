# %% [markdown]
# # ==== 【index-tts-vllm-Service】 ====

# %% [markdown]
# # clear

# %%
rm -rf ~/.local/share/Trash/*
rm -rf ~/.local/share/Trash/files/*

sudo apt clean


(clean container)
conda clean --all -y
rm -rf /root/.cache/pip
rm -rf /tmp/*

# %% [markdown]
# # Image history

# %% [raw]
# docker build -t index-tts-vllm:v1.1 .
#
# docker login --username=jimmy d.watchfun.cn
#
# (save-image)
# version="1.3.0" && server_name="index-tts-vllm" && image_prefix="d.watchfun.cn/jims57" && image_name="${image_prefix}/${server_name}" && tag="v${version}" && docker commit --pause=false "${server_name}" "${image_name}:${tag}"
#
# (tag-image)
# docker tag index-tts-vllm:v1.0.0 d.watchfun.cn/jims57/index-tts-vllm:v1.0.0
#
# (push-image-only)
# version="1.3.0" && server_name="index-tts-vllm" && image_prefix="d.watchfun.cn/jims57" && image_name="${image_prefix}/${server_name}" && tag="v${version}" && docker push "${image_name}:${tag}"
#
# (save-and-push-image)
# version="1.3.0" && server_name="index-tts-vllm" && image_prefix="d.watchfun.cn/jims57" && image_name="${image_prefix}/${server_name}" && tag="v${version}" && docker commit --pause=false "${server_name}" "${image_name}:${tag}" && docker push "${image_name}:${tag}"
#
# (start-docker)
# ===[Linux run] ====
# version="1.3.0" && server_name="index-tts-vllm" && image_prefix="d.watchfun.cn/jims57" && image_name="${image_prefix}/${server_name}" && tag="v${version}" && docker rm "${server_name}" -f && docker run --gpus all -it -p 7860:6006 -p 8080:8080 -p 9000:9000 -p 9001:9001 -p 9002:9002 -p 9003:9003 --shm-size=4g -w /mnt/index-tts-vllm -v /mnt/index-tts-vllm/checkpoints:/mnt/index-tts-vllm/checkpoints -v /mnt/index-tts-vllm/assets:/mnt/index-tts-vllm/assets -v /mnt/index-tts-vllm/logs:/mnt/index-tts-vllm/logs -v /mnt/index-tts-vllm/savedAudioFiles:/mnt/index-tts-vllm/savedAudioFiles --name "${server_name}" "${image_name}:${tag}" /bin/bash -c "export PATH="/root/miniconda3/envs/index-tts-vllm/bin:$PATH" && /root/miniconda3/envs/index-tts-vllm/bin/python api_server.py --model_dir ./checkpoints/Index-TTS-1.5-vLLM > /mnt/index-tts-vllm/logs/api_server.log 2>&1 & tail -f /dev/null"
#
# ===[Macos run](no-mount) ====
# version="1.0" && server_name="index-tts-vllm" && image_prefix="d.watchfun.cn/jims57" && image_name="${image_prefix}/${server_name}" && tag="v${version}" && docker rm "${server_name}" -f && docker run --gpus all -it -p 7860:6006 -p 8080:8080 -p 9000:9000 -p 9001:9001 -p 9002:9002 -p 9003:9003 --shm-size=2g -w /mnt/index-tts-vllm --name "${server_name}" "${image_name}:${tag}" /bin/bash -c "bash /root/.jupyter_startup.sh;cd /mnt/index-tts-vllm && /api/bin/python api.py; /bin/bash"
# ===[Macos run](with--mount) ====
# version="1.3.0" && server_name="index-tts-vllm" && image_prefix="d.watchfun.cn/jims57" && image_name="${image_prefix}/${server_name}" && tag="v${version}" && docker rm "${server_name}" -f && docker run --gpus all -it -p 7860:6006 -p 8080:8080 -p 9000:9000 -p 9001:9001 -p 9002:9002 -p 9003:9003 --shm-size=2g -w /mnt/index-tts-vllm -v /Users/mac/Documents/GitHub/aliyun_serverless_fc3/code/app:/mnt/index-tts-vllm --name "${server_name}" "${image_name}:${tag}" /bin/bash -c "bash /root/.jupyter_startup.sh;cd /mnt/index-tts-vllm && /api/bin/python api.py; /bin/bash"
#
# v1.2.1:
#     * bugfix: don't send empty stream with header info if api_server.py is not started or down
# v1.2.0:
#     * use wqDenoiser to denoise audio in /denoiseAudio api
# v1.0.7:
#     * add mp3 support
# v1.0.6:
#     * /cloneVoice api will call api_server.py to generate wav based on sent text
#     * add /denoiseAudio and /cloneVoice api
#     * add sessionID for /denoiseAudio and /cloneVoice api
#     * [important] install ffmpeg
# v1.0.5:
#     * save audio files into savedAudioFiles if saveAudioFiles = true
#     * bugfix: add 12 bytes header info properly in /tts ws in api.py
# v1.0.4:
#     * add api.py
# v1.0.3:
#     * add index-tts-vllm to path
# v1.0.2:
#     * install ninja
# v1.0.1:
#     * download model to checkpoints
# v1.0.0:
#     * install index-tts-vllm

# %% [markdown]
# # Aliyun ACR

# %% [raw]
# docker login --username=jimmy@1904289922758417 crpi-e59jvk2aewsjh4xc.cn-shanghai.personal.cr.aliyuncs.com
# pwd: watchfun.cn888
#
# version="1.3.0"
# server_name="index-tts-vllm"
# image_prefix_watch="d.watchfun.cn/jims57"
# image_name_watch="${image_prefix_watch}/${server_name}"
# image_prefix="crpi-e59jvk2aewsjh4xc.cn-shanghai.personal.cr.aliyuncs.com/watchfun-fc3-space"
# image_name="${image_prefix}/${server_name}"
# tag="v${version}"
#
# (tag-image-for-acr)
# docker tag "${image_name_watch}:${tag}" "${image_name}:${tag}"
#
#
# (push-image-to-arc)
# docker push "${image_name}:${tag}"
#
#
# (pull-image-from-acr)
# docker pull "${image_prefix}":"${tag}"

# %% [markdown]
# # Run Docker containers

# %% [markdown]
# ## [Test on local MacOS]

# %% [markdown]
# Step 1: Build index-tts-vllm Docker image
#         change version in: /Users/mac/Documents/GitHub/aliyun_serverless_fc3/my-info/build_docker_image_from_dockerfile.bash
#
#         cd /Users/mac/Documents/GitHub/aliyun_serverless_fc3/my-info && bash ./build_docker_image_from_dockerfile.bash
#
# Step 2: Run index-tts-vllm Docker container
#         a. change version in /Users/mac/Documents/GitHub/aliyun_serverless_fc3/my-info/run_index-tts-vllm_docker_from_local_macos_docker_image.bash
#
#         b. run this:
#         cd /Users/mac/Documents/GitHub/aliyun_serverless_fc3/my-info && bash run_index-tts-vllm_docker_from_local_macos_docker_image.bash

# %% [markdown]
# ## [For WQ docker image]

# %% [raw]
# docker login --username=jimmy d.watchfun.cn
#
# version="1.3.0"
# server_name="index-tts-vllm"
# image_prefix="d.watchfun.cn/jims57"
# image_name="${image_prefix}/index-tts-vllm"
# tag="v${version}"

# %% [markdown]
# # SpeakerID
# d10bb92ab03c9e8c301a3ab2ca11fba3
# jay_promptvn

# %% [markdown]
# # Other

# %% [raw]
# source /api/bin/activate
#
# deactivate
#
# cd /mnt/index-tts-vllm && /api/bin/python api.py
#
# git clone --single-branch --branch "3.2【add_ubuntu_cpp】" https://github.com/jims57/rnnoise.git
#
# /api/bin/python -m pip install requests
#
# mv /mnt/index-tts-vllm-checkpoints/* /mnt/index-tts-vllm/checkpoints/
# mv /mnt/index-tts-vllm/assets/denoiseAudios /mnt/index-tts-vllm/
# /mnt/index-tts-vllm/assets/wqDenoiser
#
# conda activate index-tts-vllm
# conda deactivate
#
# docker exec -it index-tts-vllm /bin/bash
#
# (copy api.py to server)
# scp -i /Users/mac/.ssh/id_vastai -P 58188 /Users/mac/Documents/GitHub/index-tts-vllm/api.py root@122.29.135.205:/mnt/index-tts-vllm/assets/
# mv -f /mnt/index-tts-vllm/assets/api.py /mnt/index-tts-vllm/
#
# head -n 6 /mnt/index-tts-vllm/api.py
#
# (usage)
# python api.py --port 9001 --index-tts-url http://localhost:6006
# /root/miniconda3/envs/index-tts-vllm/bin/python api_server.py --model_dir ./checkpoints/Index-TTS-1.5-vLLM
#
# (save logs with date)
# LOG_FILE="/mnt/index-tts-vllm/logs/api-server-py-log-$(date +%Y-%m-%d).log" && /root/miniconda3/envs/index-tts-vllm/bin/python api_server.py --model_dir ./checkpoints/Index-TTS-1.5-vLLM > "$LOG_FILE" 2>&1 &
# LOG_FILE="/mnt/index-tts-vllm/logs/api-py-log-$(date +%Y-%m-%d).log" && python api.py --port 9001 --index-tts-url http://localhost:6006 > "$LOG_FILE" 2>&1 &
#
#
# (check logs)
# tail -f /mnt/index-tts-vllm/logs/api_server.log
#
# (process)
# ps aux | grep api.py
# ps aux | grep api_server
#
# kill - 9 654
# kill -9 100290 101140 101179
#
# (check pcm)
# cd /Users/mac/Documents/GitHub/index-tts-vllm/my-info/utils/combine_saved_audios/pcm/combined_pcm_files && python combine_pcm_streams_into_single_pcm.py -c
#
# （tmux）
# tmux new -s root
#
# (process)
# ps aux | grep 'api.py'
# ps aux | grep 'api_server.py'
